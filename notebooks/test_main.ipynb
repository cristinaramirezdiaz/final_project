# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from functions import *

# %%
df = pd.read_csv('../data/loan_approval_dataset.csv')
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df2 = pd.read_csv('../data/train.csv')
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
tabla = {'columnas1' : df.columns, 'columnas2' : df2.columns}
tabla = pd.DataFrame(tabla)
tabla
# Out:
#                     columnas1          columnas2
# 0                     loan_id            Loan_ID
# 1            no_of_dependents             Gender
# 2                   education            Married
# 3               self_employed         Dependents
# 4                income_annum          Education
# 5                 loan_amount      Self_Employed
# 6                   loan_term    ApplicantIncome
# 7                 cibil_score  CoapplicantIncome
# 8    residential_assets_value         LoanAmount
# 9     commercial_assets_value   Loan_Amount_Term
# 10        luxury_assets_value     Credit_History
# 11           bank_asset_value      Property_Area
# 12                loan_status        Loan_Status

# %%
df[' loan_term'].unique()
# Out:
# array([12,  8, 20, 10,  4,  2, 18, 16, 14,  6])

# %%
df2['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
gender_distribution = df2['Gender'].value_counts(normalize=True)
married_distribution = df2['Married'].value_counts(normalize=True)

# Generar datos sintéticos para df2 basado en estas distribuciones
df['Gender'] = np.random.choice(gender_distribution.index, size=len(df), p=gender_distribution.values)
df['Married'] = np.random.choice(married_distribution.index, size=len(df), p=married_distribution.values)

# Mostrar un resumen de los datos generados
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.head(2)
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
#
#    loan_status  Gender Married
# 0     Approved    Male     Yes
# 1     Rejected  Female      No

# %%
df2.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status', 'Gender',
#        'Married'],
#       dtype='object')

# %%
df = df[['Gender', 'Married', ' no_of_dependents', ' education', ' self_employed', 
         ' income_annum', ' loan_amount', ' loan_status']]
df
# Out:
#       Gender Married   no_of_dependents      education  self_employed  \
# 0       Male     Yes                  2       Graduate             No
# 1     Female      No                  0   Not Graduate            Yes
# 2       Male     Yes                  3       Graduate             No
# 3       Male     Yes                  3       Graduate             No
# 4       Male     Yes                  5   Not Graduate            Yes
# ...      ...     ...                ...            ...            ...
# 4264    Male     Yes                  5       Graduate            Yes
# 4265    Male     Yes                  0   Not Graduate            Yes
# 4266    Male     Yes                  2   Not Graduate             No
# 4267    Male     Yes                  1   Not Graduate             No
# 4268    Male     Yes                  1       Graduate             No
#
#        income_annum   loan_amount  loan_status
# 0           9600000      29900000     Approved
# ...

# %%
df2 = df2[['Gender', 'Married','Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'LoanAmount', 'Loan_Status']]
df2
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
#      LoanAmount Loan_Status
# ...

# %%
name_columns(df)
df
# Out:
#       gender married  no_of_dependents      education self_employed  \
# 0       Male     Yes                 2       Graduate            No
# 1     Female      No                 0   Not Graduate           Yes
# 2       Male     Yes                 3       Graduate            No
# 3       Male     Yes                 3       Graduate            No
# 4       Male     Yes                 5   Not Graduate           Yes
# ...      ...     ...               ...            ...           ...
# 4264    Male     Yes                 5       Graduate           Yes
# 4265    Male     Yes                 0   Not Graduate           Yes
# 4266    Male     Yes                 2   Not Graduate            No
# 4267    Male     Yes                 1   Not Graduate            No
# 4268    Male     Yes                 1       Graduate            No
#
#       income_annum  loan_amount loan_status
# 0          9600000     29900000    Approved
# 1          4100000     12200000    Rejected
# ...

# %%
name_columns(df2)
df2
# Out:
#      gender married dependents     education self_employed  applicantincome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
#      loanamount loan_status
# ...

# %%
remove_last_digits(df, 'income_annum', 2)
remove_last_digits(df, 'loan_amount', 4)
# Out:
#       gender married  no_of_dependents      education self_employed  \
# 0       Male     Yes                 2       Graduate            No
# 1     Female      No                 0   Not Graduate           Yes
# 2       Male     Yes                 3       Graduate            No
# 3       Male     Yes                 3       Graduate            No
# 4       Male     Yes                 5   Not Graduate           Yes
# ...      ...     ...               ...            ...           ...
# 4264    Male     Yes                 5       Graduate           Yes
# 4265    Male     Yes                 0   Not Graduate           Yes
# 4266    Male     Yes                 2   Not Graduate            No
# 4267    Male     Yes                 1   Not Graduate            No
# 4268    Male     Yes                 1       Graduate            No
#
#      income_annum loan_amount loan_status
# 0           96000        2990    Approved
# 1           41000        1220    Rejected
# ...

# %%
multiply_column(df2, 'applicantincome')
# Out:
#      gender married dependents     education self_employed  applicantincome  \
# 0      Male      No          0      Graduate            No            70188
# 1      Male     Yes          1      Graduate            No            54996
# 2      Male     Yes          0      Graduate           Yes            36000
# 3      Male     Yes          0  Not Graduate            No            30996
# 4      Male      No          0      Graduate            No            72000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No            34800
# 610    Male     Yes         3+      Graduate            No            49272
# 611    Male     Yes          1      Graduate            No            96864
# 612    Male     Yes          2      Graduate            No            90996
# 613  Female      No          0      Graduate           Yes            54996
#
#      loanamount loan_status
# ...

# %%
df2 = replace_approval_status(df2, 'loan_status')

# %%
df = rename_columns(df)
df2 = rename_columns(df2)

# %%
df_final = pd.concat([df, df2], axis=0)
df_final
# Out:
#      gender married dependents      education self_employed income  \
# 0      Male     Yes          2       Graduate            No  96000
# 1    Female      No          0   Not Graduate           Yes  41000
# 2      Male     Yes          3       Graduate            No  91000
# 3      Male     Yes          3       Graduate            No  82000
# 4      Male     Yes          5   Not Graduate           Yes  98000
# ..      ...     ...        ...            ...           ...    ...
# 609  Female      No          0       Graduate            No  34800
# 610    Male     Yes         3+       Graduate            No  49272
# 611    Male     Yes          1       Graduate            No  96864
# 612    Male     Yes          2       Graduate            No  90996
# 613  Female      No          0       Graduate           Yes  54996
#
#     loan_amount loan_status
# 0          2990    Approved
# 1          1220    Rejected
# 2          2970    Rejected
# 3          3070    Rejected
# ...

# %%
df_final = strip_all_columns(df_final)

# %%
df_final.isnull().sum()
# Out:
# gender           13
# married           3
# dependents       15
# education         0
# self_employed    32
# income            0
# loan_amount      22
# loan_status       0
# dtype: int64

# %%
df_final.dropna(inplace=True)
df_final
# Out:
#      gender married dependents     education self_employed income loan_amount  \
# 0      Male     Yes          2      Graduate            No  96000        2990
# 1    Female      No          0  Not Graduate           Yes  41000        1220
# 2      Male     Yes          3      Graduate            No  91000        2970
# 3      Male     Yes          3      Graduate            No  82000        3070
# 4      Male     Yes          5  Not Graduate           Yes  98000        2420
# ..      ...     ...        ...           ...           ...    ...         ...
# 609  Female      No          0      Graduate            No  34800        71.0
# 610    Male     Yes         3+      Graduate            No  49272        40.0
# 611    Male     Yes          1      Graduate            No  96864       253.0
# 612    Male     Yes          2      Graduate            No  90996       187.0
# 613  Female      No          0      Graduate           Yes  54996       133.0
#
#     loan_status
# ...

# %%
df_final.duplicated().sum()
df_final.drop_duplicates(inplace=True)
df_final
# Out:
#      gender married dependents     education self_employed income loan_amount  \
# 0      Male     Yes          2      Graduate            No  96000        2990
# 1    Female      No          0  Not Graduate           Yes  41000        1220
# 2      Male     Yes          3      Graduate            No  91000        2970
# 3      Male     Yes          3      Graduate            No  82000        3070
# 4      Male     Yes          5  Not Graduate           Yes  98000        2420
# ..      ...     ...        ...           ...           ...    ...         ...
# 609  Female      No          0      Graduate            No  34800        71.0
# 610    Male     Yes         3+      Graduate            No  49272        40.0
# 611    Male     Yes          1      Graduate            No  96864       253.0
# 612    Male     Yes          2      Graduate            No  90996       187.0
# 613  Female      No          0      Graduate           Yes  54996       133.0
#
#     loan_status
# ...

# %%
df_final['gender'].value_counts()
# Out:
# gender
# Male      3941
# Female     852
# Name: count, dtype: int64

# %%
df_final['married'].value_counts()
# Out:
# married
# Yes    3097
# No     1696
# Name: count, dtype: int64

# %%
df_final['dependents'].value_counts()
# Out:
# dependents
# 4     750
# 3     725
# 0     710
# 2     707
# 1     694
# 5     672
# 0     309
# 1      91
# 2      91
# 3+     44
# Name: count, dtype: int64

# %%
df_final = remove_plus_sign(df_final, 'dependents')

# %%
df_final['dependents'].value_counts()
# Out:
# dependents
# 0    1019
# 2     798
# 1     785
# 3     769
# 4     750
# 5     672
# Name: count, dtype: int64

# %%
df_final['education'].value_counts()
# Out:
# education
# Graduate        2555
# Not Graduate    2238
# Name: count, dtype: int64

# %%
df_final['self_employed'].value_counts()
# Out:
# self_employed
# No     2575
# Yes    2218
# Name: count, dtype: int64

# %%
df_final.dtypes
# Out:
# gender           object
# married          object
# dependents       object
# education        object
# self_employed    object
# income           object
# loan_amount      object
# loan_status      object
# dtype: object

# %%
df_final = convert_columns_to_float(df_final, 'income', 'loan_amount')
df_final.dtypes
# Out:
# gender            object
# married           object
# dependents        object
# education         object
# self_employed     object
# income           float64
# loan_amount      float64
# loan_status       object
# dtype: object

# %%
df_final['loan_status'].value_counts()
# Out:
# loan_status
# Approved    3019
# Rejected    1774
# Name: count, dtype: int64

# %%
df_final
# Out:
#      gender married dependents     education self_employed   income  \
# 0      Male     Yes          2      Graduate            No  96000.0
# 1    Female      No          0  Not Graduate           Yes  41000.0
# 2      Male     Yes          3      Graduate            No  91000.0
# 3      Male     Yes          3      Graduate            No  82000.0
# 4      Male     Yes          5  Not Graduate           Yes  98000.0
# ..      ...     ...        ...           ...           ...      ...
# 609  Female      No          0      Graduate            No  34800.0
# 610    Male     Yes          3      Graduate            No  49272.0
# 611    Male     Yes          1      Graduate            No  96864.0
# 612    Male     Yes          2      Graduate            No  90996.0
# 613  Female      No          0      Graduate           Yes  54996.0
#
#      loan_amount loan_status
# 0         2990.0    Approved
# 1         1220.0    Rejected
# 2         2970.0    Rejected
# 3         3070.0    Rejected
# ...
